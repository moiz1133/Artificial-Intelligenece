# %%
import numpy as np
import pandas as pd
df = pd.read_csv('TrainingSet.csv')

# %%
y_train = df['plant'].values
x_train = df[['leaf.length', 'leaf.width', 'flower.length', 'flower.width']].values

# %% [markdown]
# # Creating method of KNN

# %%
from scipy.stats import mode
 
#Euclidean Distance
def eucledian(p1,p2):
    dist = np.sqrt(np.sum((p1-p2)**2))
    return dist
#Function to calculate KNN
def predict(x_train, y , x_input, k):
    op_labels = []
    #Loop through the Datapoints to be classified
    for item in x_input: 
        #Array to store distances
        point_dist = []
        #Loop through each training Data
        for j in range(len(x_train)): 
            distances = eucledian(np.array(x_train[j,:]) , item) 
            #Calculating the distance
            point_dist.append(distances) 
        point_dist = np.array(point_dist) 
        #Sorting the array while preserving the index
        #Keeping the first K datapoints
        dist = np.argsort(point_dist)[:k] 
        #Labels of the K datapoints from above
        labels = y[dist]
         
        #Majority voting
        lab = mode(labels) 
        lab = lab.mode[0]
        op_labels.append(lab)
 
    return op_labels

# %%
test_data = pd.read_csv('TestSet1.csv')
x_test = test_data[['leaf.length', 'leaf.width', 'flower.length', 'flower.width']].values

# %% [markdown]
# # Predicting from self-made method and Scikit Learn

# %%
#Applying our function 
from sklearn.neighbors import KNeighborsClassifier
import time

k_values = [3,5,7]
prediction = []
times = {}

for i in k_values:
    #predictions from self made formula
    start_time = time.time()
    y_test = predict(x_train,y_train,x_test , i)
    times['Time for k = ' + str(i) + ' (Self)'] = (time.time() - start_time)
    
    prediction.append(y_test)
    
    
    #predictions from scikit learn
    classifier = KNeighborsClassifier(n_neighbors=i)
    start_time = time.time()
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    times['Time for k = ' + str(i) + ' (Scikit)'] = (time.time() - start_time)
    
    prediction.append(list(y_pred))

# %%
result = pd.concat([pd.DataFrame(x_test), pd.DataFrame(prediction[0]), pd.DataFrame(prediction[1]), pd.DataFrame(prediction[2]), pd.DataFrame(prediction[3]), pd.DataFrame(prediction[4]), pd.DataFrame(prediction[5])], axis=1)
result.columns = ['leaf.length', 'leaf.width', 'flower.length', 'flower.width','k3','k3_scikit','k5','k5_scikit','k7','k7_scikit']
result
# Out:
#     leaf.length  leaf.width  flower.length  flower.width          k3  \
# 0           4.4         2.9            1.4           0.2     Arctica
# 1           4.6         3.1            1.5           0.2     Arctica
# 2           4.6         3.4            1.4           0.3     Arctica
# 3           4.7         3.2            1.3           0.2     Arctica
# 4           4.9         3.0            1.4           0.2     Arctica
# 5           4.9         3.1            1.5           0.1     Arctica
# 6           4.9         2.4            3.3           1.0   Harlequin
# 7           4.9         2.5            4.5           1.7   Harlequin
# 8           5.0         3.6            1.4           0.2     Arctica
# 9           5.0         3.4            1.5           0.2     Arctica
# 10          5.1         3.5            1.4           0.2     Arctica
# 11          5.2         2.7            3.9           1.4   Harlequin
# 12          5.4         3.9            1.7           0.4     Arctica
# 13          5.5         2.3            4.0           1.3   Harlequin
# 14          5.7         2.8            4.5           1.3   Harlequin
# 15          5.8         2.7            5.1           1.9  Carolinian
# 16          6.3         3.3            4.7           1.6   Harlequin
# 17          6.3         3.3            6.0           2.5  Carolinian
# 18          6.3         2.9            5.6           1.8  Carolinian
# 19          6.4         3.2            4.5           1.5   Harlequin
# 20          6.5         2.8            4.6           1.5   Harlequin
# 21          6.5         3.0            5.8           2.2  Carolinian
# 22          6.6         2.9            4.6           1.3   Harlequin
# 23          6.7         2.5            5.8           1.8  Carolinian
# 24          6.9         3.1            4.9           1.5   Harlequin
# 25          7.0         3.2            4.7           1.4   Harlequin
# 26          7.1         3.0            5.9           2.1  Carolinian
# 27          7.2         3.6            6.1           2.5  Carolinian
# 28          7.3         2.9            6.3           1.8  Carolinian
# 29          7.6         3.0            6.6           2.1  Carolinian
#
#      k3_scikit          k5   k5_scikit          k7   k7_scikit
# 0      Arctica     Arctica     Arctica     Arctica     Arctica
# 1      Arctica     Arctica     Arctica     Arctica     Arctica
# 2      Arctica     Arctica     Arctica     Arctica     Arctica
# 3      Arctica     Arctica     Arctica     Arctica     Arctica
# 4      Arctica     Arctica     Arctica     Arctica     Arctica
# 5      Arctica     Arctica     Arctica     Arctica     Arctica
# 6    Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 7    Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 8      Arctica     Arctica     Arctica     Arctica     Arctica
# 9      Arctica     Arctica     Arctica     Arctica     Arctica
# 10     Arctica     Arctica     Arctica     Arctica     Arctica
# 11   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 12     Arctica     Arctica     Arctica     Arctica     Arctica
# 13   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 14   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 15  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 16   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 17  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 18  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 19   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 20   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 21  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 22   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 23  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 24   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 25   Harlequin   Harlequin   Harlequin   Harlequin   Harlequin
# 26  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 27  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 28  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian
# 29  Carolinian  Carolinian  Carolinian  Carolinian  Carolinian

# %% [markdown]
# # Time for prediction by both methods

# %%
times
# Out:
# {'Time for k = 3 (Self)': 0.04487943649291992,
#  'Time for k = 3 (Scikit)': 0.006009578704833984,
#  'Time for k = 5 (Self)': 0.04388284683227539,
#  'Time for k = 5 (Scikit)': 0.0019953250885009766,
#  'Time for k = 7 (Self)': 0.04189634323120117,
#  'Time for k = 7 (Scikit)': 0.002991199493408203}

# %% [markdown]
# # Check Predictions

# %%
precentage = (sum(((result['k3'] == result['k3_scikit']) == (result['k5'] == result['k5_scikit'])) == (result['k7'] == result['k7_scikit']))/30)*100

str(precentage) + '% of entries are equal'
# Out:
# '100.0% of entries are equal'

# %%
result.to_csv('result.csv', index=False)
